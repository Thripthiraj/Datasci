# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from scipy.stats import skew   
import pylab as p

# %%
df=pd.read_csv(r'C:\Users\Gaurav\Downloads\Ecommerce - UK Retailer.csv',engine='python')

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
print(df["Country"][0:5]) #to print specific column data of mentioned index
# Out:
# 0    United Kingdom
# 1    United Kingdom
# 2    United Kingdom
# 3    United Kingdom
# 4    United Kingdom
# Name: Country, dtype: object

# %%
print(df["Country"][2]) # printing specific index data
# Out:
# United Kingdom

# %%
print(df[["Country",'CustomerID']]) # multiple column print
# Out:
#                Country  CustomerID
# 0       United Kingdom     17850.0
# 1       United Kingdom     17850.0
# 2       United Kingdom     17850.0
# 3       United Kingdom     17850.0
# 4       United Kingdom     17850.0
# ...                ...         ...
# 541904          France     12680.0
# 541905          France     12680.0
# 541906          France     12680.0
# 541907          France     12680.0
# 541908          France     12680.0
#
# [541909 rows x 2 columns]

# %%
print(df.iloc[2:4]) # to get record of specific index
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
print(df.loc[2:4])
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.loc[(df["Country"]=='Australia') & (df["Quantity"]==4)] #filtering data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 201       536389    35004G           SET OF 3 GOLD FLYING DUCKS         4
# 205       536389     22726           ALARM CLOCK BAKELIKE GREEN         4
# 206       536389     22727            ALARM CLOCK BAKELIKE RED          4
# 17071     537676     21906              PHARMACIE FIRST AID TIN         4
# 34677     539419     22728            ALARM CLOCK BAKELIKE PINK         4
# 34681     539419     20685                DOORMAT RED RETROSPOT         4
# 59115     541271     22429           ENAMEL MEASURING JUG CREAM         4
# 75184     542542     21115                ROSE CARAVAN DOORSTOP         4
# 75186     542542     22785  SQUARECUSHION COVER PINK UNION FLAG         4
# 75187     542542     22786        CUSHION COVER PINK UNION JACK         4
# 75188     542542     22192                BLUE DINER WALL CLOCK         4
# 75189     542542     22193                 RED DINER WALL CLOCK         4
# ...

# %%
df.sort_values("Country",ascending=True)
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 344571    567085     23328  SET 6 SCHOOL MILK BOTTLES IN CRATE        12
# 270069   C560540     23240   SET OF 4 KNICK KNACK TINS DOILEY         -1
# 270070   C560540     23237      SET OF 4 KNICK KNACK TINS LEAF        -1
# 270071   C560540     23236                  DOILEY STORAGE TIN        -1
# 270072   C560540     23235            STORAGE TIN VINTAGE LEAF        -1
# ...          ...       ...                                 ...       ...
# 282768    561658    84559B            3D SHEET OF CAT STICKERS         1
# 282769    561658     84549       CROCHET WHITE RABBIT KEYRING          1
# 282770    561658     22840          ROUND CAKE TIN VINTAGE RED         1
# 282756    561658     22752        SET 7 BABUSHKA NESTING BOXES         1
# 282775    561658    47559B                 TEA TIME OVEN GLOVE         1
#
#             InvoiceDate  UnitPrice  CustomerID      Country
# ...

# %%
df.sort_values(["Country","Quantity"],ascending=[1,0])
# Out:
#        InvoiceNo StockCode                    Description  Quantity  \
# 321304    565145     22492        MINI PAINT SET VINTAGE       1152
# 468139    576394     23084             RABBIT NIGHT LIGHT       960
# 321303    565145     21915         RED  HARMONICA IN BOX        720
# 193922    553546     15036      ASSORTED COLOURS SILK FAN       600
# 45536     540267     22492        MINI PAINT SET VINTAGE        576
# ...          ...       ...                            ...       ...
# 323444    565303     21558  SKULL LUNCH BOX WITH CUTLERY          1
# 323447    565303     22196   SMALL HEART MEASURING SPOONS         1
# 323451    565303     23084             RABBIT NIGHT LIGHT         1
# 323452    565303     22549               PICTURE DOMINOES         1
# 323457    565303     23127      FELTCRAFT GIRL NICOLE KIT         1
#
#              InvoiceDate  UnitPrice  CustomerID      Country
# 321304    9/1/2011 13:50       0.55     12415.0    Australia
# ...

# %%
df["Total"]=df["Quantity"]+df["UnitPrice"]
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country  Total
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom   8.55
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom   9.39
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom  10.75
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom   9.39
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom   9.39

# %%
df=df.drop(columns=["Total"])

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df['x']=df['Quantity']+df['UnitPrice']

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country      x
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom   8.55
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom   9.39
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom  10.75
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom   9.39
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom   9.39

# %%
#col=list(df.columns.values) it is used to rearange columns
#df=df[[col[-3]]+col[0:5]+col[7:9]]
#df.head()

# %%
df.loc[(df["Country"]=="Australia") & (df["Quantity"]<=4)] # filtering data
# Out:
#        InvoiceNo StockCode                   Description  Quantity  \
# 201       536389    35004G    SET OF 3 GOLD FLYING DUCKS         4
# 203       536389    85014A  BLACK/BLUE POLKADOT UMBRELLA         3
# 204       536389     22193          RED DINER WALL CLOCK         2
# 205       536389     22726    ALARM CLOCK BAKELIKE GREEN         4
# 206       536389     22727     ALARM CLOCK BAKELIKE RED          4
# ...          ...       ...                           ...       ...
# 380014    569723     23108    SET OF 10 LED DOLLY LIGHTS         2
# 380016    569723    85014B        RED RETROSPOT UMBRELLA         3
# 380017    569723    85014A  BLACK/BLUE POLKADOT UMBRELLA         3
# 433987   C574019     22738     RIBBON REEL SNOWY VILLAGE      -120
# 438979   C574344      POST                       POSTAGE        -1
#
#             InvoiceDate  UnitPrice  CustomerID    Country       x
# 201     12/1/2010 10:03       6.35     12431.0  Australia   10.35
# ...

# %%
df.loc[(df["Quantity"]<2)&(df["UnitPrice"]<1)]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 114       536381     22262             FELT EGG COSY CHICKEN         1
# 127       536381     22261       FELT EGG COSY WHITE RABBIT          1
# 128       536381     84832  ZINC WILLIE WINKIE  CANDLE STICK         1
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 541739    581571     23182    TOILET SIGN OCCUPIED OR VACANT         1
# 541749    581571     44234          ASSORTED CIRCULAR MOBILE         1
# 541837    581580     21790                VINTAGE SNAP CARDS         1
# 541842    581580     20974       12 PENCILS SMALL TUBE SKULL         1
# 541846    581580     22695               WICKER WREATH SMALL         1
#
#             InvoiceDate  UnitPrice  CustomerID         Country      x
# ...

# %%
df.loc[(df["Quantity"]>1) & (df["Quantity"]<4) & (df["UnitPrice"]==1)] #conditional filter
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 37317     539457         M                             Manual         2
# 173085    551652      POST                            POSTAGE         2
# 307771    563928    90030C  BROWN KUKUI COCONUT SEED NECKLACE         3
# 369718    569089         M                             Manual         3
# 388688    570448         M                             Manual         3
# 492254    578099      POST                            POSTAGE         2
#
#              InvoiceDate  UnitPrice  CustomerID         Country    x
# 37317   12/17/2010 17:24        1.0         NaN  United Kingdom  3.0
# 173085    5/3/2011 12:03        1.0     12643.0          France  3.0
# 307771   8/21/2011 15:17        1.0     17059.0  United Kingdom  4.0
# 369718   9/30/2011 12:03        1.0     13764.0  United Kingdom  4.0
# 388688  10/10/2011 14:55        1.0     13224.0  United Kingdom  4.0
# ...

# %%
x=df.loc[((df["Quantity"]==1)|(df["Quantity"]==2))&(df["UnitPrice"]==1)]
x
# Out:
#        InvoiceNo StockCode                  Description  Quantity  \
# 10113     537225         M                       Manual         1
# 37317     539457         M                       Manual         2
# 130294    547444      POST                      POSTAGE         1
# 142718    548631         M                       Manual         1
# 173085    551652      POST                      POSTAGE         2
# 179049    552259         M                       Manual         1
# 246052    558679         M                       Manual         1
# 247505    558771     35265  COLOURFUL FLOWER FRUIT BOWL         1
# 396988    571106         M                       Manual         1
# 419485    572832         M                       Manual         1
# 492254    578099      POST                      POSTAGE         2
# 504904    578996         M                       Manual         1
# 533022    581005     85225         BLING KEY RING STAND         1
#
# ...

# %%
new_x=x.sort_values("Quantity",ascending=False) # sorting above filtered data
new_x
# Out:
#        InvoiceNo StockCode                  Description  Quantity  \
# 37317     539457         M                       Manual         2
# 173085    551652      POST                      POSTAGE         2
# 492254    578099      POST                      POSTAGE         2
# 10113     537225         M                       Manual         1
# 130294    547444      POST                      POSTAGE         1
# 142718    548631         M                       Manual         1
# 179049    552259         M                       Manual         1
# 246052    558679         M                       Manual         1
# 247505    558771     35265  COLOURFUL FLOWER FRUIT BOWL         1
# 396988    571106         M                       Manual         1
# 419485    572832         M                       Manual         1
# 504904    578996         M                       Manual         1
# 533022    581005     85225         BLING KEY RING STAND         1
#
# ...

# %%
new_x.reset_index(drop=True,inplace=True)
new_x
# Out:
#    InvoiceNo StockCode                  Description  Quantity  \
# 0     539457         M                       Manual         2
# 1     551652      POST                      POSTAGE         2
# 2     578099      POST                      POSTAGE         2
# 3     537225         M                       Manual         1
# 4     547444      POST                      POSTAGE         1
# 5     548631         M                       Manual         1
# 6     552259         M                       Manual         1
# 7     558679         M                       Manual         1
# 8     558771     35265  COLOURFUL FLOWER FRUIT BOWL         1
# 9     571106         M                       Manual         1
# 10    572832         M                       Manual         1
# 11    578996         M                       Manual         1
# 12    581005     85225         BLING KEY RING STAND         1
#
#          InvoiceDate  UnitPrice  CustomerID         Country    x
# ...

# %%
new_x.iloc[2] #Printing record of filtered sorted with new index number
# Out:
# InvoiceNo               578099
# StockCode                 POST
# Description            POSTAGE
# Quantity                     2
# InvoiceDate    11/23/2011 8:05
# UnitPrice                    1
# CustomerID               12452
# Country            Switzerland
# x                            3
# Name: 2, dtype: object

# %%
z=df.loc[((df["Country"].str.contains("nce")) | (df["Country"].str.contains('United')))&(df["Quantity"]==1)] #printing word containg specific words
z
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 113       536381     71270                  PHOTO CLIP LINE         1
# 114       536381     22262            FELT EGG COSY CHICKEN         1
# 115       536381     22637            PIGGY BANK RETROSPOT          1
# 118       536381     21166       COOK WITH WINE METAL SIGN          1
# 120       536381    37444A  YELLOW BREAKFAST CUP AND SAUCER         1
# ...          ...       ...                              ...       ...
# 541851    581580     22721    SET OF 3 CAKE TINS SKETCHBOOK         1
# 541855    581580     21351         CINAMMON & ORANGE WREATH         1
# 541856    581580     22698   PINK REGENCY TEACUP AND SAUCER         1
# 541857    581580     22567          20 DOLLY PEGS RETROSPOT         1
# 541859    581580     37500      TEA TIME TEAPOT IN GIFT BOX         1
#
#             InvoiceDate  UnitPrice  CustomerID         Country     x
# ...

# %%
z.sort_values("Country",ascending=False)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 113       536381     71270                      PHOTO CLIP LINE         1
# 362220    568411     22179              SET 10 NIGHT OWL LIGHTS         1
# 362212    568411     22069        BROWN  PIRATE TREASURE CHEST          1
# 362213    568411     22089        PAPER BUNTING VINTAGE PAISLEY         1
# 362214    568411     22109         FULL ENGLISH BREAKFAST PLATE         1
# ...          ...       ...                                  ...       ...
# 347284    567296      POST                              POSTAGE         1
# 127068    547194    84596B   SMALL DOLLY MIX DESIGN ORANGE BOWL         1
# 127064    547194     22895  SET OF 2 TEA TOWELS APPLE AND PEARS         1
# 127062    547194     22992               REVOLVER WOODEN RULER          1
# 104468    545181      POST                              POSTAGE         1
#
#             InvoiceDate  UnitPrice  CustomerID         Country      x
# ...

# %%
q=df.loc[~df["Country"].str.contains("United")] # not containing
q
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 26        536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 27        536370     22727        ALARM CLOCK BAKELIKE RED         24
# 28        536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 29        536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 30        536370     21883                 STARS GIFT TAPE         24
# ...          ...       ...                              ...       ...
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID Country      x
# 26       12/1/2010 8:45       3.75     12583.0  France  27.75
# ...

# %%
df.loc[(df["Country"].str.contains("lands")) | (df["Country"].str.contains("nce"))]
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 26        536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 27        536370     22727        ALARM CLOCK BAKELIKE RED         24
# 28        536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 29        536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 30        536370     21883                 STARS GIFT TAPE         24
# ...          ...       ...                              ...       ...
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID Country      x
# 26       12/1/2010 8:45       3.75     12583.0  France  27.75
# ...

# %%
#df.loc[df['Country']=='Australia','Country']='Amma'
#df.sort_values('Country',inplace=False)

# %%
df.loc[df['Quantity']>20,['Country']]='IND'
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country      x
# ...

# %%
df.loc[df['Quantity']>20]
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 9         536367     84879       ASSORTED COLOUR BIRD ORNAMENT        32
# 26        536370     22728           ALARM CLOCK BAKELIKE PINK        24
# 27        536370     22727           ALARM CLOCK BAKELIKE RED         24
# 30        536370     21883                    STARS GIFT TAPE         24
# 31        536370     10002         INFLATABLE POLITICAL GLOBE         48
# ...          ...       ...                                 ...       ...
# 541876    581585     84945  MULTI COLOUR SILVER T-LIGHT HOLDER        24
# 541882    581585     21916     SET 12 RETRO WHITE CHALK STICKS        24
# 541883    581585     84692         BOX OF 24 COCKTAIL PARASOLS        25
# 541891    581586     23275    SET OF 3 HANGING OWLS OLLIE BEAK        24
# 541892    581586     21217       RED RETROSPOT ROUND CAKE TINS        24
#
#             InvoiceDate  UnitPrice  CustomerID Country      x
# ...

# %%
df.loc[df['Country']=='IND',['Country']]='other'
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country      x
# ...

# %%
df.loc[df['Quantity']>20]
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 9         536367     84879       ASSORTED COLOUR BIRD ORNAMENT        32
# 26        536370     22728           ALARM CLOCK BAKELIKE PINK        24
# 27        536370     22727           ALARM CLOCK BAKELIKE RED         24
# 30        536370     21883                    STARS GIFT TAPE         24
# 31        536370     10002         INFLATABLE POLITICAL GLOBE         48
# ...          ...       ...                                 ...       ...
# 541876    581585     84945  MULTI COLOUR SILVER T-LIGHT HOLDER        24
# 541882    581585     21916     SET 12 RETRO WHITE CHALK STICKS        24
# 541883    581585     84692         BOX OF 24 COCKTAIL PARASOLS        25
# 541891    581586     23275    SET OF 3 HANGING OWLS OLLIE BEAK        24
# 541892    581586     21217       RED RETROSPOT ROUND CAKE TINS        24
#
#             InvoiceDate  UnitPrice  CustomerID Country      x
# ...

# %%
df.loc[df['Country']=='other',['UnitPrice','x']]=['Nill','total']
df.loc[df['Country']=='other']
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 9         536367     84879       ASSORTED COLOUR BIRD ORNAMENT        32
# 26        536370     22728           ALARM CLOCK BAKELIKE PINK        24
# 27        536370     22727           ALARM CLOCK BAKELIKE RED         24
# 30        536370     21883                    STARS GIFT TAPE         24
# 31        536370     10002         INFLATABLE POLITICAL GLOBE         48
# ...          ...       ...                                 ...       ...
# 541876    581585     84945  MULTI COLOUR SILVER T-LIGHT HOLDER        24
# 541882    581585     21916     SET 12 RETRO WHITE CHALK STICKS        24
# 541883    581585     84692         BOX OF 24 COCKTAIL PARASOLS        25
# 541891    581586     23275    SET OF 3 HANGING OWLS OLLIE BEAK        24
# 541892    581586     21217       RED RETROSPOT ROUND CAKE TINS        24
#
#             InvoiceDate UnitPrice  CustomerID Country      x
# ...

# %%
df.groupby('Quantity').mean().sort_values('Quantity',ascending=False)
# Out:
#           CustomerID
# Quantity
#  80995       16446.0
#  74215       12346.0
#  12540       13256.0
#  5568            NaN
#  4800        12901.0
# ...              ...
# -9058            NaN
# -9360        15838.0
# -9600            NaN
# -74215       12346.0
# -80995       16446.0
#
# [722 rows x 1 columns]

# %%
df['count']=1
df.groupby(['Country']).count()['count']# getting count
# Out:
# Country
# Australia                  569
# Austria                    354
# Bahrain                     15
# Belgium                   1807
# Brazil                      24
# Canada                     114
# Channel Islands            631
# Cyprus                     559
# Czech Republic              12
# Denmark                    236
# EIRE                      6508
# European Community          55
# Finland                    551
# France                    7134
# Germany                   7954
# Greece                     131
# Hong Kong                  202
# Iceland                    147
# Israel                     207
# Italy                      723
# Japan                      126
# Lebanon                     44
# Lithuania                   24
# Malta                      117
# Netherlands                637
# Norway                     770
# Poland                     295
# Portugal                  1326
# RSA                         58
# Saudi Arabia                10
# ...

# %%
df['count']=1
df.groupby(['Country','Quantity']).count()['count']
# Out:
# Country    Quantity
# Australia  -120        1
#            -100        1
#            -86         1
#            -36         2
#            -24         2
#                       ..
# other       4800       1
#             5568       1
#             12540      1
#             74215      1
#             80995      1
# Name: count, Length: 1358, dtype: int64

# %%
df.Country.sum()

# %%
df.Country.count
