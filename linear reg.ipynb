# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv(r'C:\Users\Gaurav\Desktop\Raj\headbrain.csv')

# %%
df.shape
# Out:
# (237, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Gender               237 non-null    int64
#  1   Age Range            237 non-null    int64
#  2   Head Size(cm^3)      237 non-null    int64
#  3   Brain Weight(grams)  237 non-null    int64
# dtypes: int64(4)
# memory usage: 7.5 KB

# %%
df.head()
# Out:
#    Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0       1          1             4512                 1530
# 1       1          1             3738                 1297
# 2       1          1             4261                 1335
# 3       1          1             3777                 1282
# 4       1          1             4177                 1590

# %%
df=df.rename(columns={'Head Size(cm^3)':'HeadSize'})

# %%
df=df.rename(columns={'Brain Weight(grams)':'BrainWeight'})

# %%
x=df.iloc[:,2:-1].values
# this way the x column will be in 2d as you can see in printed x there are two sq. bracket .
# we don't need to reshape it later
y=df['BrainWeight'].values

# %%
x
# Out:
# array([[4512],
#        [3738],
#        [4261],
#        [3777],
#        [4177],
#        [3585],
#        [3785],
#        [3559],
#        [3613],
#        [3982],
#        [3443],
#        [3993],
#        [3640],
#        [4208],
#        [3832],
#        [3876],
#        [3497],
#        [3466],
#        [3095],
#        [4424],
#        [3878],
#        [4046],
#        [3804],
#        [3710],
#        [4747],
#        [4423],
#        [4036],
#        [4022],
#        [3454],
#        [4175],
#        [3787],
#        [3796],
#        [4103],
#        [4161],
#        [4158],
#        [3814],
#        [3527],
#        [3748],
#        [3334],
#        [3492],
#        [3962],
#        [3505],
#        [4315],
#        [3804],
#        [3863],
#        [4034],
#        [4308],
#        [3165],
#        [3641],
#        [3644],
#        [3891],
#        [3793],
#        [4270],
#        [4063],
#        [4012],
#        [3458],
#        [3890],
#        [4166],
# ...

# %%
y
# Out:
# array([1530, 1297, 1335, 1282, 1590, 1300, 1400, 1255, 1355, 1375, 1340,
#        1380, 1355, 1522, 1208, 1405, 1358, 1292, 1340, 1400, 1357, 1287,
#        1275, 1270, 1635, 1505, 1490, 1485, 1310, 1420, 1318, 1432, 1364,
#        1405, 1432, 1207, 1375, 1350, 1236, 1250, 1350, 1320, 1525, 1570,
#        1340, 1422, 1506, 1215, 1311, 1300, 1224, 1350, 1335, 1390, 1400,
#        1225, 1310, 1560, 1330, 1222, 1415, 1175, 1330, 1485, 1470, 1135,
#        1310, 1154, 1510, 1415, 1468, 1390, 1380, 1432, 1240, 1195, 1225,
#        1188, 1252, 1315, 1245, 1430, 1279, 1245, 1309, 1412, 1120, 1220,
#        1280, 1440, 1370, 1192, 1230, 1346, 1290, 1165, 1240, 1132, 1242,
#        1270, 1218, 1430, 1588, 1320, 1290, 1260, 1425, 1226, 1360, 1620,
#        1310, 1250, 1295, 1290, 1290, 1275, 1250, 1270, 1362, 1300, 1173,
#        1256, 1440, 1180, 1306, 1350, 1125, 1165, 1312, 1300, 1270, 1335,
#        1450, 1310, 1027, 1235, 1260, 1165, 1080, 1127, 1270, 1252, 1200,
# ...

# %%
plt.scatter(x,y)
plt.show()

# %%
from sklearn.model_selection import train_test_split #for split
from sklearn.linear_model import LinearRegression # for linear reg
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30)
print(x_train,y_train)
# Out:
# [[4103]
#  [4315]
#  [3362]
#  [4430]
#  [3181]
#  [3558]
#  [3228]
#  [3171]
#  [3372]
#  [3572]
#  [4208]
#  [3740]
#  [3814]
#  [3589]
#  [3268]
#  [3878]
#  [3156]
#  [3830]
#  [3586]
#  [3458]
#  [3248]
#  [3071]
#  [3779]
#  [3695]
#  [2773]
#  [3594]
#  [3524]
#  [4057]
#  [4423]
#  [3532]
#  [3903]
#  [3391]
#  [3933]
#  [3700]
#  [3506]
#  [3779]
#  [3318]
#  [3571]
#  [3334]
#  [3856]
#  [3391]
#  [3613]
#  [3473]
#  [3916]
#  [3710]
#  [3203]
#  [3394]
#  [3993]
#  [3399]
#  [3647]
#  [3490]
#  [3641]
#  [3165]
#  [3692]
#  [3302]
#  [3438]
#  [3640]
#  [3503]
#  [4200]
#  [3389]
#  [2864]
#  [2857]
#  [3479]
#  [3680]
#  [3556]
#  [3866]
#  [2720]
#  [4166]
#  [3415]
#  [3309]
#  [3687]
#  [2989]
#  [3899]
#  [3615]
#  [4036]
#  [3267]
#  [3451]
#  [3727]
#  [3858]
#  [3853]
#  [3900]
#  [3796]
#  [4381]
#  [3495]
#  [3907]
#  [3577]
#  [4022]
#  [3824]
#  [3787]
#  [3527]
#  [3354]
#  [3654]
#  [3318]
#  [4046]
#  [3782]
#  [4177]
#  [3803]
#  [3249]
#  [4488]
#  [4747]
# ...

# %%
print(x_test,y_test)
# Out:
# [[2937]
#  [4034]
#  [4261]
#  [3170]
#  [3935]
#  [3533]
#  [4161]
#  [3685]
#  [4012]
#  [3082]
#  [3703]
#  [3571]
#  [4005]
#  [3851]
#  [3716]
#  [4121]
#  [3443]
#  [3642]
#  [3835]
#  [3566]
#  [3095]
#  [3661]
#  [3793]
#  [3979]
#  [3067]
#  [3707]
#  [3352]
#  [3399]
#  [4204]
#  [3297]
#  [3358]
#  [3497]
#  [3360]
#  [4053]
#  [3609]
#  [3104]
#  [3058]
#  [3499]
#  [3748]
#  [3466]
#  [3492]
#  [3899]
#  [3000]
#  [4032]
#  [3704]
#  [3891]
#  [3548]
#  [3662]
#  [3165]
#  [3344]
#  [4158]
#  [3406]
#  [3383]
#  [3777]
#  [3175]
#  [3505]
#  [3292]
#  [3561]
#  [3124]
#  [4063]
#  [3530]
#  [3666]
#  [3632]
#  [3876]
#  [3982]
#  [4046]
#  [3246]
#  [3791]
#  [3233]
#  [3269]
#  [3284]
#  [3850]] [1070 1422 1335 1178 1330 1210 1405 1350 1400 1180 1350 1295 1280 1405
#  1300 1380 1340 1205 1315 1306 1340 1320 1350 1324 1150 1235 1170 1173
#  1380 1220 1190 1358 1095 1312 1210 1080 1120 1275 1350 1292 1250 1380
# ...

# %%
reg=LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.predict(x_test)
# Out:
# array([1089.90103099, 1395.90750683, 1459.2288104 , 1154.89602541,
#        1368.29160792, 1256.15432142, 1431.33396301, 1298.55448945,
#        1389.77064041, 1130.3485597 , 1303.57556198, 1266.75436343,
#        1387.81800109, 1344.85993611, 1307.20189214, 1420.17602406,
#        1231.04895877, 1286.55970507, 1340.39676053, 1265.35962106,
#        1133.97488986, 1291.85972608, 1328.68092463, 1380.56534077,
#        1126.1643326 , 1304.69135588, 1205.66464765, 1218.77522592,
#        1443.32874739, 1190.32248159, 1207.33833849, 1246.11217636,
#        1207.89623544, 1401.20752784, 1277.35440544, 1136.48542613,
#        1123.65379633, 1246.67007331, 1316.1282433 , 1237.46477367,
#        1244.71743399, 1358.24946286, 1107.47478485, 1395.34960988,
#        1303.85451045, 1356.01787507, 1260.33854853, 1292.13867455,
#        1153.50128304, 1203.43305986, 1430.49711759, 1220.72786524,
#        1214.31205034, 1324.21774905, 1156.29076777, 1248.34376415,
# ...

# %%
y_test
# Out:
# array([1070, 1422, 1335, 1178, 1330, 1210, 1405, 1350, 1400, 1180, 1350,
#        1295, 1280, 1405, 1300, 1380, 1340, 1205, 1315, 1306, 1340, 1320,
#        1350, 1324, 1150, 1235, 1170, 1173, 1380, 1220, 1190, 1358, 1095,
#        1312, 1210, 1080, 1120, 1275, 1350, 1292, 1250, 1380, 1090, 1425,
#        1220, 1224, 1460, 1230, 1237, 1220, 1432, 1220, 1290, 1282, 1200,
#        1320, 1075, 1127, 1165, 1390, 1252, 1270, 1163, 1405, 1375, 1287,
#        1180, 1260, 1104, 1241, 1246, 1412], dtype=int64)

# %%
reg.score(x_test,y_test)
# Out:
# 0.5002448199237758
